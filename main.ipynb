# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_mat = pd.read_csv("student-mat.csv", sep=";")
df_por = pd.read_csv("student-por.csv", sep=";")

print(df_mat.shape)
print(df_por.shape)
# Out:
# (395, 33)
# (649, 33)

# %%
key_cols = ["school", "sex", "age", "address", "famsize", "Pstatus",
            "Medu", "Fedu", "Mjob", "Fjob", "reason", "nursery", "internet"]

# %%
print(df_mat[key_cols].duplicated().sum())
print(df_por[key_cols].duplicated().sum())
# Out:
# 4
# 12

# %%
df= pd.merge(df_mat, df_por, on=key_cols, suffixes=("_mat", "_por"))
print(df.shape)
# Out:
# (382, 53)
